# %%
from pymongo import MongoClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pymongo import MongoClient
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in C:\Users\Ajitesh Channa\anaconda3\Lib\site-packages (4.17.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in C:\Users\Ajitesh Channa\anaconda3\Lib\site-packages (from pymongo) (2.8.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\Ajitesh Channa\anaconda3\python.exe -m pip install --upgrade pip

# %%
client = MongoClient("mongodb+srv://djadhwanin_db_user:tmc8xbGQjrFP2GsL@ecom-pydantic.3g4asxt.mongodb.net/?appName=ecom-pydantic")

# %%
# !pip install pymongo
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/Ajitesh Channa/.local/bin/python3.12.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
db = client["ecom_db"]

collection = db["orders"]

print("connectted to mongo db")
# Out:
# connectted to mongo db

# %%
order = {
    "name": "Men Casual Shirt",
    "price": 999,
    "category": "men"
}

collection.insert_one(order)
# Out:
# InsertOneResult(ObjectId('69d2231a7462e5e5729ae40f'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)

print("Multiple Products Inserted ✅")
# Out:
# Multiple Products Inserted ✅

# %%
# 🧪 🔹 CELL 6 — View All Products
all_products = collection.find()

for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('69d2208b7462e5e5729ae40b'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'men'}
# {'_id': ObjectId('69d220d47462e5e5729ae40c'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('69d220d47462e5e5729ae40d'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('69d220d47462e5e5729ae40e'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %% [markdown]
# TEXT 2 Nosql

# %%
product = collection.find_one({"name": "Kurti"})

print(product)
# Out:
# {'_id': ObjectId('69d220d47462e5e5729ae40d'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
men_products = collection.find({"category": "kids"})

for p in men_products:
    print(p)
# Out:
# {'_id': ObjectId('69d220d47462e5e5729ae40e'), 'name': 'Kids Jacket', 'price': 1599, 'category': 'kids'}

# %% [markdown]
# UPDATE

# %%
collection.update_one(
    {"name": "Jeans"},
    {"$set": {"price": 1399}}
)

print("Product Updated ✅")
# Out:
# Product Updated ✅

# %% [markdown]
# DELETE

# %%
collection.delete_one({"name": "Kids Jacket"})

print("Product Deleted ✅")
# Out:
# Product Deleted ✅

# %%
collection.delete_many({})

print("All Products Deleted ✅")
# Out:
# All Products Deleted ✅

# %%
collection.drop()

print("Collection Dropped ✅")
# Out:
# Collection Dropped ✅
